# %%
# Jupyter notebook for the lab:
# Building a webhook server for monitoring Cisco Catalyst Center operations using Intent APIs and Event Notifications

# Lab 1 - understand issues and events from collections

import json

def load_json(filename):
    with open(filename, 'r') as file:
        return json.load(file)

# Load the data from files
issues_collection = load_json('Issues_collection_verified.json')
issues_enrichment = load_json('Issues_enrichment_verified.json')
events_collection = load_json('Events_collection_verified.json')

# Print the first record of each file
print("First record from Issues Collection:")
print(json.dumps(issues_collection[0], indent=4))

print("First record from Issues Enrichment:")
print(json.dumps(issues_enrichment[0], indent=4))

print("First record from Events Collection:")
print(json.dumps(events_collection[0], indent=4))
# Out:
# First record from Issues Collection:
# {
#     "issueId": "933c8a49-a995-4932-b934-3169c3a5e8a6",
#     "name": "Network Device MSX-OTT02-9800CL-06.cisco.com is unreachable from Cisco DNA Center",
#     "siteId": "",
#     "deviceId": "72f959ad-9df9-41a7-b0f9-47e566ca7765",
#     "deviceRole": "",
#     "aiDriven": "",
#     "clientMac": "",
#     "issue_occurence_count": 4,
#     "status": "active",
#     "priority": "",
#     "category": "",
#     "last_occurence_time": 1701564255412
# }
# First record from Issues Enrichment:
# {
#     "issueDetails": {
#         "issue": [
#             {
#                 "issueId": "933c8a49-a995-4932-b934-3169c3a5e8a6",
#                 "issueSource": "Cisco DNA",
#                 "issueCategory": "Availability",
#                 "issueName": "wlc_unreachable",
#                 "issueDescription": "This network device MSX-OTT02-9800CL-06.cisco.com is unreachable from Cisco DNA Center. The device role is ACCESS.",
#                 "issueEntity": "network_device",
#                 "issueEntityValue": "72f959ad-9df9-41a7-b0f9-47e566ca7765",
#                 "issueSeverity": "HIGH",
#                 "issuePriority": "P1",
#                 "issueSummary": "Network Device MSX-OTT02-9800CL-06.cisco.com is unreachable from Cisco DNA Center",
#                 "issueTimestamp": 1701564255412,
#                 "deviceId": "72f959ad-9df9-41a7-b0f9-47e566ca7765",
#                 "suggestedActions": [
#                     {
#                         "message": "From the Cisco DNA Center, verify whether the last hop is reachable."
#                     },
#                     {
#                         "message": "Verify that the physical port(s) on the network device associated with the network device discovery(IP) is UP."
#                     },
#                     {
#                         "message": "Verify access to the device."
#                     }
#                 ],
#                 "impactedHosts": []
#             }
#         ]
#     }
# }
# First record from Events Collection:
# {
#     "version": "1.0.0",
#     "instanceId": "1edbcd94-3ddb-4411-b7d0-7c03984d67dc",
#     "eventId": "NETWORK-DEVICES-3-215",
#     "namespace": "ASSURANCE",
#     "name": null,
#     "description": null,
#     "type": "NETWORK",
#     "category": "WARN",
#     "domain": "Know Your Network",
#     "subDomain": "Devices",
#     "severity": 3,
#     "source": "ndp",
#     "timestamp": 1683915145700,
#     "tags": [],
#     "details": {
#         "interfaceDescription": "*** Link to C2960CX - GR018 ***",
#         "_name": "switch_interface_input_output_discards",
#         "_entity_type": "NetworkDevice",
#         "threshold": "10",
#         "ctProfileName": "global",
#         "_key": "NetworkDevice:e498b146-2e75-4036-81a2-2b259406ff82:10608:Lab-Core-Switch.siplab.net:Global/Test Area3/TEST-03 #151857:/9ffa6c59-a3f9-4452-9025-b0a650110e83/4cff9971-f474-4dba-8b7e-6f7a7ffbf20e/befd6706-4d06-475c-914e-bfdab6c6273e/:global",
#         "type": "issue",
#         "ctProfileId": "global",
#         "floorId": "",
#         "o_ifIndex": 10608,
#         "areaName": "Global/Test Area3",
#         "rxDiscardPercent": 0,
#         "__type": "assurance_triggers",
#         "siteType": "building",
#         "deviceType": "Cisco 3750 Stackable Switches",
#         "deviceUuid": "e498b146-2e75-4036-81a2-2b259406ff82",
#         "entityType": "network_device",
#         "deviceOS": "12.2(40)SE",
#         "_eventTime": 1683915145301,
#         "nwDeviceName": "Lab-Core-Switch.siplab.net",
#         "deviceGroupHierarchyId": "/e0d6dd68-5f4a-4243-8bb4-d876dc369be3/35da52d6-1070-460e-81fc-851b00507661/",
#         "_mostRecent": 1683915145301,
#         "eventUniqueId": "10.219.0.2",
#         "deviceFamily": "Switches and Hubs",
#         "priority": "P3",
#         "txDiscardPercent": 99.68,
#         "buildingName": "Global/Test Area3/TEST-03 #151857",
#         "siteHierarchyGraphId": "/9ffa6c59-a3f9-4452-9025-b0a650110e83/4cff9971-f474-4dba-8b7e-6f7a7ffbf20e/befd6706-4d06-475c-914e-bfdab6c6273e/",
#         "_appId": "assurance_issue_triggers",
#         "tagIdList": "[]",
#         "status": "active",
#         "managementIpAddr": "10.219.0.2",
#         "_tenantId": "63c5840e4948be16a4704824",
#         "eventSource": "Network Device",
#         "_count": 1,
#         "instanceId": "1edbcd94-3ddb-4411-b7d0-7c03984d67dc",
#         "scope": "global",
#         "_primary_key": "NetworkDevice:e498b146-2e75-4036-81a2-2b259406ff82",
#         "interfaceName": "GigabitEthernet2/0/8",
#         "floorName": "",
#         "__timestamp": 1683915145619,
#         "severity": "MEDIUM",
#         "deviceRole": "ACCESS",
#         "_suppression": 0,
#         "entityId": "e498b146-2e75-4036-81a2-2b259406ff82",
#         "_sink_version": "1.0.0",
#         "buildingId": "befd6706-4d06-475c-914e-bfdab6c6273e",
#         "areaId": "4cff9971-f474-4dba-8b7e-6f7a7ffbf20e",
#         "siteHierarchy": "Global/Test Area3/TEST-03 #151857",
#         "deviceModel": "CAT0936Z4E6",
#         "category": "connected"
#     },
#     "ciscoDnaEventLink": null,
#     "note": null,
#     "tntId": "63c5840e4948be16a4704824",
#     "context": null,
#     "userId": null,
#     "i18n": null,
#     "eventHierarchy": null,
#     "message": null,
#     "messageParams": null,
#     "additionalDetails": {},
#     "parentInstanceId": null,
#     "network": null,
#     "isSimulated": false,
#     "startTime": 1683915145702,
#     "isPrivateEvent": false,
#     "dnacIP": null,
#     "tenantId": "SYS0"
# }

# %%
# Jupyter notebook for the lab:
# Building a webhook server for monitoring Cisco Catalyst Center operations using Intent APIs and Event Notifications

# Lab 1 - understand issues and events from collections

import json

# Function to load JSON data from a file
def load_json(filename):
    with open(filename, 'r') as file:
        return json.load(file)

# Load the data from files
issues_collection = load_json('Issues_collection_verified.json')
issues_enrichment = load_json('Issues_enrichment_verified.json')
events_collection = load_json('Events_collection_verified.json')

# Adjusting the extraction of issues from 'issues_enrichment'
issues_enrichment_data = issues_enrichment[0]['issueDetails']['issue'] if issues_enrichment else []

# Creating dictionaries for easy lookup
issues_dict = {issue['issueId']: issue for issue in issues_collection}
enrichment_dict = {issue['issueId']: issue for issue in issues_enrichment_data}

# Safely creating the events dictionary and a list of issue IDs from events
events_dict = {}
event_issue_ids = []
for event in events_collection:
    device_uuid = event.get('details', {}).get('deviceUuid')
    if device_uuid:
        events_dict[device_uuid] = event
        event_issue_ids.append(device_uuid)

# Finding common issues and devices
common_issues = set(issues_dict.keys()) & set(enrichment_dict.keys())
common_devices = set(event.get('deviceId') for event in issues_collection if event.get('deviceId')) & set(events_dict.keys())

# Print the total number of different issues
print(f"Total unique issues: {len(common_issues)}")
print(f"Unique issues: {common_issues}")

# Print all issue IDs found in issues_collection
print(f"\nTotal issues in Issues Collection: {len(issues_dict)}")
print("Issue IDs found in Issues Collection:")
for issue_id in issues_dict:
    print(issue_id)

# Print the total number of events observed and their issue IDs
print(f"\nTotal events observed: {len(events_collection)}")
print("Issue IDs observed in Events Collection:")
for issue_id in event_issue_ids:
    print(issue_id)

# Print common fields
print("\nCommon Issues:")
for issue_id in common_issues:
    print(f"Issue ID: {issue_id}")
    print("From Issues Collection:", issues_dict[issue_id])
    print("From Issues Enrichment:", enrichment_dict[issue_id])
    print()

print("Common Devices:")
for device_id in common_devices:
    if device_id in events_dict:
        print(f"Device ID: {device_id}")
        print("From Issues Collection:", issues_dict.get(device_id, 'Not Found'))
        print("From Events Collection:", events_dict[device_id])
        print()
# Out:
# Total unique issues: 1
# Unique issues: {'933c8a49-a995-4932-b934-3169c3a5e8a6'}
#
# Total issues in Issues Collection: 16
# Issue IDs found in Issues Collection:
# 933c8a49-a995-4932-b934-3169c3a5e8a6
# 57ed9444-7251-43a5-b0be-d2564627b6b7
# 1edbcd94-3ddb-4411-b7d0-7c03984d67dc
# f2b3c0c6-84ab-4bfb-8f72-bb6140eb770f
# 89535d8e-1937-419f-bf39-952b8a107ae5
# d99952c3-9a9d-4ea7-a532-d09ee25034c6
# c939d83e-2e60-4f5d-9f25-c2b5e4120483
# d7a4f455-b2d0-461e-86f7-573a2aa2c801
# ba2ab36a-7f53-42cb-b071-f393f96ca1d9
# 02e4b787-211d-48d8-9045-cbed7f02fad9
# ceb127ec-2ec0-41c6-9455-b84608ae0132
# 59572a29-feca-4588-825b-261c45723db5
# d3d8681c-75d1-4c6a-b114-1c4a0388e39c
# 3944ce19-44ba-4e37-acb3-3ed8c1745975
# e49e6223-fd44-477b-a7e1-964f12b8b0ce
# 0fa042da-76f0-490f-bd1f-69a598b40678
#
# Total events observed: 14
# Issue IDs observed in Events Collection:
# e498b146-2e75-4036-81a2-2b259406ff82
# 7a6c11fd-4d13-4a28-96b7-84bec82aeffb
# 7a6c11fd-4d13-4a28-96b7-84bec82aeffb
# e498b146-2e75-4036-81a2-2b259406ff82
#
# Common Issues:
# Issue ID: 933c8a49-a995-4932-b934-3169c3a5e8a6
# From Issues Collection: {'issueId': '933c8a49-a995-4932-b934-3169c3a5e8a6', 'name': 'Network Device MSX-OTT02-9800CL-06.cisco.com is unreachable from Cisco DNA Center', 'siteId': '', 'deviceId': '72f959ad-9df9-41a7-b0f9-47e566ca7765', 'deviceRole': '', 'aiDriven': '', 'clientMac': '', 'issue_occurence_count': 4, 'status': 'active', 'priority': '', 'category': '', 'last_occurence_time': 1701564255412}
# From Issues Enrichment: {'issueId': '933c8a49-a995-4932-b934-3169c3a5e8a6', 'issueSource': 'Cisco DNA', 'issueCategory': 'Availability', 'issueName': 'wlc_unreachable', 'issueDescription': 'This network device MSX-OTT02-9800CL-06.cisco.com is unreachable from Cisco DNA Center. The device role is ACCESS.', 'issueEntity': 'network_device', 'issueEntityValue': '72f959ad-9df9-41a7-b0f9-47e566ca7765', 'issueSeverity': 'HIGH', 'issuePriority': 'P1', 'issueSummary': 'Network Device MSX-OTT02-9800CL-06.cisco.com is unreachable from Cisco DNA Center', 'issueTimestamp': 1701564255412, 'deviceId': '72f959ad-9df9-41a7-b0f9-47e566ca7765', 'suggestedActions': [{'message': 'From the Cisco DNA Center, verify whether the last hop is reachable.'}, {'message': 'Verify that the physical port(s) on the network device associated with the network device discovery(IP) is UP.'}, {'message': 'Verify access to the device.'}], 'impactedHosts': []}
#
# Common Devices:
# Device ID: 7a6c11fd-4d13-4a28-96b7-84bec82aeffb
# From Issues Collection: Not Found
# From Events Collection: {'version': '1.0.0', 'instanceId': '8b91e70e-4f30-4cbf-b4cf-06c0cb92837b', 'eventId': 'NETWORK-NON-FABRIC_WIRED-1-200', 'namespace': None, 'name': None, 'description': None, 'type': 'NETWORK', 'category': 'ALERT', 'domain': 'Connectivity', 'subDomain': 'Non-Fabric Wired', 'severity': 1, 'source': 'Cisco DNA Assurance', 'timestamp': 1683796652944, 'tags': [], 'details': {'managementIpAddr': '192.168.80.2', 'fabricOrDeviceRole': 'DISTRIBUTION', '_name': 'switch_unreachable', '_entity_type': 'NetworkDevice', 'eventSource': 'Network Device', 'ctProfileName': 'global', 'type': 'Issue', '_key': 'NetworkDevice:7a6c11fd-4d13-4a28-96b7-84bec82aeffb:C9500-TEST-HOSTNAME.dnaclab.net:Global/Test Area1/TEST-01 #151855:/9ffa6c59-a3f9-4452-9025-b0a650110e83/1b4290ef-565f-400f-86af-80ee4b735dec/9c32724c-37cc-4b74-b40b-66b7a174fbb7/:global', 'ctProfileId': 'global', 'floorId': '', '_count': '12', 'instanceId': '8b91e70e-4f30-4cbf-b4cf-06c0cb92837b', 'areaName': 'Global/Test Area1', 'scope': 'global', '_primary_key': 'NetworkDevice:7a6c11fd-4d13-4a28-96b7-84bec82aeffb', 'needState': 'true', 'floorName': '', 'siteType': 'building', 'deviceType': 'Cisco Catalyst 9500 Switch', 'severity': 'HIGH', 'deviceUuid': '7a6c11fd-4d13-4a28-96b7-84bec82aeffb', 'deviceRole': 'DISTRIBUTION', '_suppression': '0', 'entityType': 'network_device', 'deviceOS': '17.6.3', 'nwDeviceName': 'C9500-TEST-HOSTNAME.dnaclab.net', '_eventTime': '1682773587166', 'deviceGroupHierarchyId': '/e0d6dd68-5f4a-4243-8bb4-d876dc369be3/6de1fe2a-ee98-4dae-baec-b0e10502d711/', '_mostRecent': '1683723987288', 'entityId': '7a6c11fd-4d13-4a28-96b7-84bec82aeffb', 'eventUniqueId': '192.168.80.2', 'deviceFamily': 'Switches and Hubs', 'priority': 'P1', 'buildingId': '9c32724c-37cc-4b74-b40b-66b7a174fbb7', 'siteHierarchyGraphId': '/9ffa6c59-a3f9-4452-9025-b0a650110e83/1b4290ef-565f-400f-86af-80ee4b735dec/9c32724c-37cc-4b74-b40b-66b7a174fbb7/', 'buildingName': 'Global/Test Area1/TEST-01 #151855', 'areaId': '1b4290ef-565f-400f-86af-80ee4b735dec', 'siteHierarchy': 'Global/Test Area1/TEST-01 #151855', 'deviceModel': 'FCW2248F05B', 'category': 'Availability', 'tagIdList': '[]', 'status': 'ignored'}, 'ciscoDnaEventLink': None, 'note': None, 'tntId': '63c5840e4948be16a4704824', 'context': None, 'userId': None, 'i18n': None, 'eventHierarchy': None, 'message': None, 'messageParams': None, 'additionalDetails': {}, 'parentInstanceId': None, 'network': None, 'isSimulated': False, 'startTime': 1683796652948, 'isPrivateEvent': False, 'dnacIP': None, 'tenantId': 'SYS0'}
#
# Device ID: e498b146-2e75-4036-81a2-2b259406ff82
# From Issues Collection: Not Found
# From Events Collection: {'version': '1.0.0', 'instanceId': '1edbcd94-3ddb-4411-b7d0-7c03984d67dc', 'eventId': 'NETWORK-DEVICES-3-215', 'namespace': 'ASSURANCE', 'name': None, 'description': None, 'type': 'NETWORK', 'category': 'WARN', 'domain': 'Know Your Network', 'subDomain': 'Devices', 'severity': 3, 'source': 'ndp', 'timestamp': 1683915145700, 'tags': [], 'details': {'interfaceDescription': '*** Link to C2960CX - GR018 ***', '_name': 'switch_interface_input_output_discards', '_entity_type': 'NetworkDevice', 'threshold': '10', 'ctProfileName': 'global', '_key': 'NetworkDevice:e498b146-2e75-4036-81a2-2b259406ff82:10608:Lab-Core-Switch.siplab.net:Global/Test Area3/TEST-03 #151857:/9ffa6c59-a3f9-4452-9025-b0a650110e83/4cff9971-f474-4dba-8b7e-6f7a7ffbf20e/befd6706-4d06-475c-914e-bfdab6c6273e/:global', 'type': 'issue', 'ctProfileId': 'global', 'floorId': '', 'o_ifIndex': 10608, 'areaName': 'Global/Test Area3', 'rxDiscardPercent': 0, '__type': 'assurance_triggers', 'siteType': 'building', 'deviceType': 'Cisco 3750 Stackable Switches', 'deviceUuid': 'e498b146-2e75-4036-81a2-2b259406ff82', 'entityType': 'network_device', 'deviceOS': '12.2(40)SE', '_eventTime': 1683915145301, 'nwDeviceName': 'Lab-Core-Switch.siplab.net', 'deviceGroupHierarchyId': '/e0d6dd68-5f4a-4243-8bb4-d876dc369be3/35da52d6-1070-460e-81fc-851b00507661/', '_mostRecent': 1683915145301, 'eventUniqueId': '10.219.0.2', 'deviceFamily': 'Switches and Hubs', 'priority': 'P3', 'txDiscardPercent': 99.68, 'buildingName': 'Global/Test Area3/TEST-03 #151857', 'siteHierarchyGraphId': '/9ffa6c59-a3f9-4452-9025-b0a650110e83/4cff9971-f474-4dba-8b7e-6f7a7ffbf20e/befd6706-4d06-475c-914e-bfdab6c6273e/', '_appId': 'assurance_issue_triggers', 'tagIdList': '[]', 'status': 'active', 'managementIpAddr': '10.219.0.2', '_tenantId': '63c5840e4948be16a4704824', 'eventSource': 'Network Device', '_count': 1, 'instanceId': '1edbcd94-3ddb-4411-b7d0-7c03984d67dc', 'scope': 'global', '_primary_key': 'NetworkDevice:e498b146-2e75-4036-81a2-2b259406ff82', 'interfaceName': 'GigabitEthernet2/0/8', 'floorName': '', '__timestamp': 1683915145619, 'severity': 'MEDIUM', 'deviceRole': 'ACCESS', '_suppression': 0, 'entityId': 'e498b146-2e75-4036-81a2-2b259406ff82', '_sink_version': '1.0.0', 'buildingId': 'befd6706-4d06-475c-914e-bfdab6c6273e', 'areaId': '4cff9971-f474-4dba-8b7e-6f7a7ffbf20e', 'siteHierarchy': 'Global/Test Area3/TEST-03 #151857', 'deviceModel': 'CAT0936Z4E6', 'category': 'connected'}, 'ciscoDnaEventLink': None, 'note': None, 'tntId': '63c5840e4948be16a4704824', 'context': None, 'userId': None, 'i18n': None, 'eventHierarchy': None, 'message': None, 'messageParams': None, 'additionalDetails': {}, 'parentInstanceId': None, 'network': None, 'isSimulated': False, 'startTime': 1683915145702, 'isPrivateEvent': False, 'dnacIP': None, 'tenantId': 'SYS0'}

# %%
# This is the reusable python script you can use to identify common issues and instances in issues and events
# Consider that this script uses also the issue enrichment to get more details from the issue 

import json

# Function to load JSON from a file
def load_json(filename):
    with open(filename, 'r') as file:
        data = json.load(file)
    return data

# Load the data from JSON files
issues_collection = load_json('Issues_collection_verified.json')
issues_enrichment = load_json('Issues_enrichment_verified.json')
events_collection = load_json('Events_collection_verified.json')

# Create sets to store 'issue_id' values from both collections
issue_ids_collection = {item.get('issueId') for item in issues_collection}
issue_ids_enrichment = set()

# Iterate through 'issues_enrichment' and add 'issue_id' values to the set
for item in issues_enrichment:
    issue_details = item.get('issueDetails', {})
    issues_list = issue_details.get('issue', [])
    for issue in issues_list:
        issue_id = issue.get('issueId')
        if issue_id is not None:
            issue_ids_enrichment.add(issue_id)

# Create a list to store matching 'instance_id' values
matching_instance_ids = []

# Iterate through 'events_collection' and find matching 'instance_id'
for event in events_collection:
    #issue_id = event.get('issueId')
    instance_id = event.get('instanceId')
    
    if issue_id in issue_ids_collection and issue_id in issue_ids_enrichment and instance_id:
        matching_instance_ids.append(instance_id)

# Print the matching 'instance_id' values
print("Common issues observed in the collections:")
for instance_id in matching_instance_ids:
    print(instance_id)
# Out:
# Common issues observed in the collections:
# 1edbcd94-3ddb-4411-b7d0-7c03984d67dc
# f2b3c0c6-84ab-4bfb-8f72-bb6140eb770f
# 8b91e70e-4f30-4cbf-b4cf-06c0cb92837b
# 1edbcd94-3ddb-4411-b7d0-7c03984d67dc
# e881255b-11f5-43df-976c-95a035744d51
# 03f56dc7-0c0a-419f-bc22-7f92229bac70
# 703b4e0d-dc58-469d-9837-c5c54b156da6
# f05af755-6793-44de-8a4d-d0c10131a5d5
# feb365f0-5d72-4760-a696-7e7a1937bad8
# 4343d4ed-d8f3-43cc-93f5-797be4b4e124
# 92085ad5-8115-48ff-a76e-1640df382b00
# 18d6be63-25f4-4a11-8b06-d8af7faa9b0d
# 92085ad5-8115-48ff-a76e-1640df382b00
# 57ed9444-7251-43a5-b0be-d2564627b6b7

# %%
# Lab 2 - DNAC emultion
# Get issues

import requests
import json

server_url = "http://127.0.0.1:5000/dna/system/api/v1/auth/token"
issues_url = "http://127.0.0.1:5000/dna/intent/api/v1/issues"

# Define credentials
credentials = {
    "username": "admin",
    "password": "CiscoLive100%"
}

# Request token with credentials
response = requests.post(server_url, json=credentials)
if response.status_code == 200:
    token = response.json().get("Token")
    print("Token received:", token)

    # Use the token to get issues
    headers = {"content-type": "application/json", "x-auth-token": token}
    issues_response = requests.get(issues_url, headers=headers)

    # Prettify the JSON response
    pretty_json = json.dumps(issues_response.json(), indent=4)
    print("Response from GET ISSUES:")
    print(pretty_json)
else:
    print("Failed to get token:", response.json())
# Out:
# Token received: BeHpMVYJGO6ehw9e4cqd4w5y9zkFzZiseYxlxfOzwj-GdBLuSPfO1uaSp2_nX0m0N5HSCjLsH7al7p_hEZ2yYQ
# Response from GET ISSUES:
# [
#     {
#         "aiDriven": "",
#         "category": "",
#         "clientMac": "",
#         "deviceId": "72f959ad-9df9-41a7-b0f9-47e566ca7765",
#         "deviceRole": "",
#         "issueId": "933c8a49-a995-4932-b934-3169c3a5e8a6",
#         "issue_occurence_count": 4,
#         "last_occurence_time": 1701564255412,
#         "name": "Network Device MSX-OTT02-9800CL-06.cisco.com is unreachable from Cisco DNA Center",
#         "priority": "",
#         "siteId": "",
#         "status": "active"
#     },
#     {
#         "aiDriven": "",
#         "category": "",
#         "clientMac": "",
#         "deviceId": "0ed45671-ec6f-4b66-9ab8-a919d31008f5",
#         "deviceRole": "",
#         "issueId": "57ed9444-7251-43a5-b0be-d2564627b6b7",
#         "issue_occurence_count": 1,
#         "last_occurence_time": 1701521644000,
#         "name": "Excessive time lag between Cisco DNA Center and device \"MSX-OTT02-CAT3650-01\"",
#         "priority": "",
#         "siteId": "",
#         "status": "active"
#     },
#     {
#         "aiDriven": "",
#         "category": "",
#         "clientMac": "",
#         "deviceId": "e498b146-2e75-4036-81a2-2b259406ff82",
#         "deviceRole": "",
#         "issueId": "1edbcd94-3ddb-4411-b7d0-7c03984d67dc",
#         "issue_occurence_count": 1,
#         "last_occurence_time": 1684402945330,
#         "name": "High input/output discard on interface 'GigabitEthernet2/0/8' (Interface description: *** Link to C2960CX - GR018 ***)",
#         "priority": "",
#         "siteId": "9ffa6c59-a3f9-4452-9025-b0a650110e83/4cff9971-f474-4dba-8b7e-6f7a7ffbf20e/befd6706-4d06-475c-914e-bfdab6c6273e",
#         "status": "active"
#     },
#     {
#         "aiDriven": "",
#         "category": "",
#         "clientMac": "",
#         "deviceId": "7a6c11fd-4d13-4a28-96b7-84bec82aeffb",
#         "deviceRole": "",
#         "issueId": "f2b3c0c6-84ab-4bfb-8f72-bb6140eb770f",
#         "issue_occurence_count": 1,
#         "last_occurence_time": 1684328787324,
#         "name": "Network Device C9500-TEST-HOSTNAME.dnaclab.net is unreachable from Cisco DNA Center",
#         "priority": "",
#         "siteId": "9ffa6c59-a3f9-4452-9025-b0a650110e83/1b4290ef-565f-400f-86af-80ee4b735dec/9c32724c-37cc-4b74-b40b-66b7a174fbb7",
#         "status": "active"
#     },
#     {
#         "aiDriven": "",
#         "category": "",
#         "clientMac": "",
#         "deviceId": "e498b146-2e75-4036-81a2-2b259406ff82",
#         "deviceRole": "",
#         "issueId": "1edbcd94-3ddb-4411-b7d0-7c03984d67dc",
#         "issue_occurence_count": 1,
#         "last_occurence_time": 1684402945330,
#         "name": "High input/output discard on interface 'GigabitEthernet2/0/8' (Interface description: *** Link to C2960CX - GR018 ***)",
#         "priority": "",
#         "siteId": "9ffa6c59-a3f9-4452-9025-b0a650110e83/4cff9971-f474-4dba-8b7e-6f7a7ffbf20e/befd6706-4d06-475c-914e-bfdab6c6273e",
#         "status": "active"
#     },
#     {
#         "aiDriven": "",
#         "category": "",
#         "clientMac": "",
#         "deviceId": "fd38a62e-0510-45e8-a28e-84ac10ade26e",
#         "deviceRole": "",
#         "issueId": "89535d8e-1937-419f-bf39-952b8a107ae5",
#         "issue_occurence_count": 1,
#         "last_occurence_time": 1684136281757,
#         "name": "AAA Server '172.23.80.21' state on Edge device 'OL_2202002_FES01.xpat.nhs.uk' is DEAD.",
#         "priority": "",
#         "siteId": "556bbeba-c602-4259-84f4-1c96efc9497a/4d2b5a9d-0e80-494c-93d5-55c5165dfd80/ee2150c2-bdf4-4867-b26b-5924b5734d4c",
#         "status": "active"
#     },
#     {
#         "aiDriven": "",
#         "category": "",
#         "clientMac": "",
#         "deviceId": "273918cf-77be-42d1-8f91-3f5298cfb793",
#         "deviceRole": "",
#         "issueId": "d99952c3-9a9d-4ea7-a532-d09ee25034c6",
#         "issue_occurence_count": 1,
#         "last_occurence_time": 1684136663728,
#         "name": "AP \"FF_5301007_ACP07\" disconnected from WLC.",
#         "priority": "",
#         "siteId": "556bbeba-c602-4259-84f4-1c96efc9497a/9e2b1477-ad2a-477d-869c-039d9b32769f/bb048b81-f697-4d67-9419-09ca271c8aa3/27a44084-d99b-49bd-8ea1-4eec379a4215",
#         "status": "active"
#     },
#     {
#         "aiDriven": "",
#         "category": "",
#         "clientMac": "",
#         "deviceId": null,
#         "deviceRole": "",
#         "issueId": "c939d83e-2e60-4f5d-9f25-c2b5e4120483",
#         "issue_occurence_count": 1,
#         "last_occurence_time": 1684092600000,
#         "name": "Excessive failures to connect - At least 42% increase in failures on p4twl4n1 in Global/OL/OL_BLK41.",
#         "priority": "",
#         "siteId": "556bbeba-c602-4259-84f4-1c96efc9497a/4d2b5a9d-0e80-494c-93d5-55c5165dfd80/ae346153-decf-4b2a-92a9-8e713245d049",
#         "status": "active"
#     },
#     {
#         "aiDriven": "",
#         "category": "",
#         "clientMac": "",
#         "deviceId": "dfa99274-473f-41f8-8e60-b4cca7f24939",
#         "deviceRole": "",
#         "issueId": "d7a4f455-b2d0-461e-86f7-573a2aa2c801",
#         "issue_occurence_count": 1,
#         "last_occurence_time": 1684158662423,
#         "name": "'Co-located Fabric Border and Control Plane' \"OL_INFRAS_BAC02.xpat.nhs.uk\" Lost Connectivity to the DHCP Server 172.23.244.14 in the Virtual Network GUEST",
#         "priority": "",
#         "siteId": "556bbeba-c602-4259-84f4-1c96efc9497a/4d2b5a9d-0e80-494c-93d5-55c5165dfd80/ee2150c2-bdf4-4867-b26b-5924b5734d4c",
#         "status": "active"
#     },
#     {
#         "aiDriven": "",
#         "category": "",
#         "clientMac": "",
#         "deviceId": "8a796880-5ebc-48dc-ae32-d060d14e19ab",
#         "deviceRole": "",
#         "issueId": "ba2ab36a-7f53-42cb-b071-f393f96ca1d9",
#         "issue_occurence_count": 1,
#         "last_occurence_time": 1684136642824,
#         "name": "Interface \"TenGigabitEthernet1/0/45\" (Interface description: FF_5301007_ACP07) is down on network device \"FF_5300003_FES01.xpat.nhs.uk\"",
#         "priority": "",
#         "siteId": "556bbeba-c602-4259-84f4-1c96efc9497a/9e2b1477-ad2a-477d-869c-039d9b32769f/cf0ef4bf-e263-4e4a-850f-7cbdbdb91384",
#         "status": "active"
#     },
#     {
#         "aiDriven": "",
#         "category": "",
#         "clientMac": "",
#         "deviceId": "8b4209af-2788-4d8a-bcd2-a67f2eb312ed",
#         "deviceRole": "",
#         "issueId": "02e4b787-211d-48d8-9045-cbed7f02fad9",
#         "issue_occurence_count": 1,
#         "last_occurence_time": 1684091580557,
#         "name": "The RADIUS server '172.23.80.21:1812,1813' is not responding to requests being made from the network device 'RI_38-1135_FES01.xpat.nhs.uk'",
#         "priority": "",
#         "siteId": "556bbeba-c602-4259-84f4-1c96efc9497a/6aac11c2-369f-4633-9aa9-50ce08efb12a/d84d025a-425b-4322-abd5-86cba2717941",
#         "status": "active"
#     },
#     {
#         "aiDriven": "",
#         "category": "",
#         "clientMac": "",
#         "deviceId": "e598c3c3-1677-4d29-a5ea-db20b8ad6cb8",
#         "deviceRole": "",
#         "issueId": "ceb127ec-2ec0-41c6-9455-b84608ae0132",
#         "issue_occurence_count": 1,
#         "last_occurence_time": 1684148477818,
#         "name": "AP \"OL_4902086_ACP15\" has rebooted due to a hardware or software crash.",
#         "priority": "",
#         "siteId": "556bbeba-c602-4259-84f4-1c96efc9497a/4d2b5a9d-0e80-494c-93d5-55c5165dfd80/78373e4c-8b04-4145-a493-988e5f221139/824d16cd-eb78-4787-86d1-851721a4c7d4",
#         "status": "active"
#     },
#     {
#         "aiDriven": "",
#         "category": "",
#         "clientMac": "",
#         "deviceId": null,
#         "deviceRole": "",
#         "issueId": "59572a29-feca-4588-825b-261c45723db5",
#         "issue_occurence_count": 1,
#         "last_occurence_time": 1684144800000,
#         "name": "AP(s) (5 GHz) at \"Global/OL/OL_BLK23/OL_B23_L1\" had high noise",
#         "priority": "",
#         "siteId": "556bbeba-c602-4259-84f4-1c96efc9497a/4d2b5a9d-0e80-494c-93d5-55c5165dfd80/13c6503c-a24e-4e2c-90ac-6fe5da5ddb36/2635a3b7-3ea0-48cd-96e0-1f48c8a0a3ab",
#         "status": "active"
#     },
#     {
#         "aiDriven": "",
#         "category": "",
#         "clientMac": "",
#         "deviceId": null,
#         "deviceRole": "",
#         "issueId": "d3d8681c-75d1-4c6a-b114-1c4a0388e39c",
#         "issue_occurence_count": 1,
#         "last_occurence_time": 1684152000000,
#         "name": "AP(s) (5 GHz) at \"Global/RI/RI_BLK1/RI_B1_LD\" had high interference",
#         "priority": "",
#         "siteId": "556bbeba-c602-4259-84f4-1c96efc9497a/6aac11c2-369f-4633-9aa9-50ce08efb12a/c37329bd-eb5b-42ac-9412-df352e49491f/d896e000-bfae-4981-905c-99d403549608",
#         "status": "active"
#     },
#     {
#         "aiDriven": "",
#         "category": "",
#         "clientMac": "",
#         "deviceId": "3b768713-c179-409f-878d-5b2c599511dc",
#         "deviceRole": "",
#         "issueId": "3944ce19-44ba-4e37-acb3-3ed8c1745975",
#         "issue_occurence_count": 1,
#         "last_occurence_time": 1684159029088,
#         "name": "PoE powered device connected on OL_4902044_FES01.xpat.nhs.uk Gi3/0/19 (Interface description: --) is flagged faulty due to Power Controller reports power Tstart error detected",
#         "priority": "",
#         "siteId": "556bbeba-c602-4259-84f4-1c96efc9497a/4d2b5a9d-0e80-494c-93d5-55c5165dfd80/ee2150c2-bdf4-4867-b26b-5924b5734d4c",
#         "status": "active"
#     },
#     {
#         "aiDriven": "",
#         "category": "",
#         "clientMac": "",
#         "deviceId": "6b239cb5-3694-4d30-8baf-4464bc994224",
#         "deviceRole": "",
#         "issueId": "e49e6223-fd44-477b-a7e1-964f12b8b0ce",
#         "issue_occurence_count": 1,
#         "last_occurence_time": 1684147443477,
#         "name": "AP \"OL_5701007_ACP002\" has a coverage hole.",
#         "priority": "",
#         "siteId": "556bbeba-c602-4259-84f4-1c96efc9497a/4d2b5a9d-0e80-494c-93d5-55c5165dfd80/ce00a47d-d082-4e87-a9bc-3e5229d2e8d0/68909c31-775d-4314-b941-67bc6f044993",
#         "status": "active"
#     },
#     {
#         "aiDriven": "",
#         "category": "",
#         "clientMac": "",
#         "deviceId": "6d69dc48-3b9d-4d2b-931b-a3892b039b97",
#         "deviceRole": "",
#         "issueId": "0fa042da-76f0-490f-bd1f-69a598b40678",
#         "issue_occurence_count": 1,
#         "last_occurence_time": 1684150500000,
#         "name": "The 5 GHz radio 1 on AP \"FF_6702013_ACP03\" is experiencing high utilization.",
#         "priority": "",
#         "siteId": "556bbeba-c602-4259-84f4-1c96efc9497a/9e2b1477-ad2a-477d-869c-039d9b32769f/860cc5ba-bb8f-478d-a48f-75d88909a5bd/78cacfad-0778-46ee-a72f-8d9687c8fac7",
#         "status": "active"
#     }
# ]

# %%
# Lab 2 - issue enrichment
# "issueId": "933c8a49-a995-4932-b934-3169c3a5e8a6" - existing issueId
# "issueId": "57ed9444-7251-43a5-b0be-d2564627b6b7"

# ISSUE ENRICHMENT
ISSUES_ENRICH = url = '/dna/intent/api/v1/issue-enrichment-details'
server_url = 'http://127.0.0.1:5000/dna/system/api/v1/auth/token'
BASE_URL = 'http://127.0.0.1:5000'

# Define credentials
credentials = {
    "username": "admin",
    "password": "CiscoLive100%"
}

# Request token with credentials
response = requests.post(server_url, json=credentials)
if response.status_code == 200:
    token = response.json().get('Token')
    print("Token received:", token)

headers = {'content-type': 'application/json','x-auth-token': token, 'entity-type': 'issue_id', 'entity-value': '6d69dc48-3b9d-4d2b-931b-a3892b039b97'}
response = requests.get(BASE_URL + ISSUES_ENRICH, headers=headers, verify=False)
issue_enrich = response.json()
print ("\nPretty print response:\n",json.dumps(issue_enrich,indent=4))
# Out:
# Token received: nC72zjzatMHMpn5o9jSZT-1L7mZYEqMSSWewvwJNS31ZxY5sOIALotcX1U19PKSHWvrsBVh0rgGuoVvC7chbnA
#
# Pretty print response:
#  {
#     "error": "Issue not found"
# }
