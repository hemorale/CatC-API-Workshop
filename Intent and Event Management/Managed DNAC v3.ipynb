# %%
def get_token(dnac_ip,uname,passwd):
    token = requests.post(
       'https://' + str(dnac_ip)+ '/dna/system/api/v1/auth/token',
       auth=HTTPBasicAuth(
           username=uname,
           password=passwd
       ),
       headers={'content-type': 'application/json'},
       verify=False,
    )
    data = token.json()
    return data['Token']

# %%
# Get list of sites
def get_sites(BASE_URL, URL, headers):
    response = requests.get(BASE_URL + URL,
                            headers=headers, verify=False)
    return response.json()['response']

# %%
# Get list of sites
def get_site_health (BASE_URL, URL, headers):
    response = requests.get(BASE_URL + URL,
                            headers=headers, verify=False)
    print(response)
    return response.json()['response']

# %%
# Generic Get API
def get_api (BASE_URL, URL, headers):
    response = requests.get(BASE_URL + URL,
                            headers=headers, verify=False)
    print(response)
    return response.json()['response']

# %%
# Get list of issues
# https://dnac-79.infra.ciscomsx.com/dna/intent/api/v1/issues
def get_issues(dnac_ip,username,password):
    URL = "dna/intent/api/v1/issues?startTime=<startTime>&endTime=<endTime>&siteId=<siteId>&deviceId=<deviceId>&macAddress=<macAddress>&priority=<priority>&aiDriven=<aiDriven>&issueStatus=<issueStatus>"
    response = requests.get("https://"+dnac_ip + URL,
                            verify=False)
    return response.json()['response']

# %%
# DNAC code
import requests   # We use Python "requests" module to do HTTP GET query
from requests.auth import HTTPBasicAuth  #DNAC uses basic Authentication to get a token
import json       # Import JSON encoder and decode module

import urllib3

# Disable the InsecureRequestWarning
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# Define variables
dnac_ip = "198.18.129.100"
username = "admin"
password = "C1sco12345"

# Authentication
BASE_URL = 'https://198.18.129.100'
AUTH_URL = '/dna/system/api/v1/auth/token'
USERNAME = 'admin'
PASSWORD = 'C1sco12345'

# URLs
SITE_URL = '/dna/intent/api/v1/site'
SITE_COUNT_URL = '/dna/intent/api/v1/site/count'
MEMBERSHIP_SITE_URL = '/dna/intent/api/v1/membership/{site_id}'
SITE_HEALTH_URL = '/dna/intent/api/v1/site-health'
ISSUES_URL = url = '/dna/intent/api/v1/issues'

token = get_token(dnac_ip, username, password)
#issues = get_issues(dnac_ip, username, password)

print(token)
# Out:
# eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..gCE-U-hccGd_FJXleoj7PP4ibxz-7CcsUYzyg1-9eQdFmbnnP37rCvR2Bs9KSN7bmicqYqy6G8_J-iqRMRD4RS57o4Pf9Egz1BrszlBGqg17Z3RsbMYvzuZ-Jm8hYtTRctSSABrgasTf0XQpDDvl0rd-AeGWRJuAMAXFIbqx086LC98pVewcuygXc4Ru1FNUyEhEmfrNnzJMJZUnHc0pT5WfwwujrztNJ5cBhsHrwIl4ez9BOaBWOfcpkpoh0Zm4rASresGAlLF9mRqk-ybCmuERJAyUktwLDzdLz7dbdOBoRmNWkLe75T3YeImQQf2AOUeIudNYPc8Ab0o0Kdb-jg

# %%
# Headers
headers = {'content-type': 'application/json','x-auth-token': token}
issues_list = get_api (BASE_URL, ISSUES_URL, headers)
print ("\nPretty print response:\n",json.dumps(issues_list,indent=4))
# Out:
# <Response [200]>
#
# Pretty print response:
#  [
#     {
#         "issueId": "729ca016-798b-42ef-8a34-a78476cf1d31",
#         "name": "Excessive time lag between Cisco DNA Center and device \"isr4331.dcloud.cisco.com\"",
#         "siteId": "",
#         "deviceId": "28d5bb60-79c5-4dec-b2f6-97404a108cbc",
#         "deviceRole": "",
#         "aiDriven": "No",
#         "clientMac": "",
#         "issue_occurence_count": 1,
#         "status": "active",
#         "priority": "",
#         "category": "",
#         "last_occurence_time": 1738634630000
#     }
# ]

# %%
# ISSUE ENRICHMENT
ISSUES_ENRICH = url = '/dna/intent/api/v1/issue-enrichment-details'

headers = {'content-type': 'application/json','x-auth-token': token, 'entity_type': "issue_id", 'entity_value': "729ca016-798b-42ef-8a34-a78476cf1d31"}
response = requests.get(BASE_URL + ISSUES_ENRICH, headers=headers, verify=False)
issue_enrich = response.json()
print ("\nPretty print response:\n",json.dumps(issue_enrich,indent=4))
# Out:
# Pretty print response:
#  {
#     "issueDetails": {
#         "issue": [
#             {
#                 "issueId": "729ca016-798b-42ef-8a34-a78476cf1d31",
#                 "issueSource": "Cisco DNA",
#                 "issueCategory": "Device",
#                 "issueName": "device_time_drift",
#                 "issueDescription": "The time on Cisco DNA Center and Device \"isr4331.dcloud.cisco.com\" has drifted too far apart. Cisco DNA Center cannot process the device data accurately if the time difference is more than 3 minutes.",
#                 "issueEntity": "network_device",
#                 "issueEntityValue": "28d5bb60-79c5-4dec-b2f6-97404a108cbc",
#                 "issueSeverity": "HIGH",
#                 "issuePriority": "P3",
#                 "issueSummary": "Excessive time lag between Cisco DNA Center and device \"isr4331.dcloud.cisco.com\"",
#                 "issueTimestamp": 1738634630000,
# ...

# %%
# Headers
headers = {'content-type': 'application/json','x-auth-token': token}

sites = get_sites(BASE_URL, SITE_URL, headers)

# %%
print ("\nPretty print response:\n",json.dumps(sites,indent=4))
# Out:
# Pretty print response:
#  [
#     {
#         "additionalInfo": [],
#         "name": "Global",
#         "instanceTenantId": "662079cb4939f459d3890116",
#         "id": "68b27cdf-11b5-4fe0-bd43-97cd2ca22126",
#         "siteHierarchy": "68b27cdf-11b5-4fe0-bd43-97cd2ca22126",
#         "siteNameHierarchy": "Global"
#     },
#     {
#         "parentId": "2c0f2c76-7b97-4d65-b83f-63f56ae91b4e",
#         "additionalInfo": [
#             {
#                 "nameSpace": "Location",
#                 "attributes": {
#                     "country": "United States",
#                     "address": "7025 Kit Creek Road, Morrisville, North Carolina 27560, United States",
#                     "latitude": "35.854988",
#                     "addressInheritedFrom": "18d26268-df22-473c-86af-55f9ecdd3dca",
#                     "type": "building",
#                     "longitude": "-78.875495"
#                 }
#             }
#         ],
#         "name": "HQ",
# ...

# %%
# Print nicely only Name, Site Name Hierarchy and Namespace

import json

json_tree = json.dumps(sites,indent=4)

data = json.loads(json_tree)

for item in data:
    name = item.get('name')
    site_name_hierarchy = item.get('siteNameHierarchy')
    namespace = None
    item_id = item.get('id')

    additional_info = item.get('additionalInfo', [])
    for info in additional_info:
        namespace = info.get('nameSpace')
        print("Id:", item_id)
        print("Name:", name)
        print("Site Name Hierarchy:", site_name_hierarchy)
        print("Namespace:", namespace)
        print()
# Out:
# Id: 18d26268-df22-473c-86af-55f9ecdd3dca
# Name: HQ
# Site Name Hierarchy: Global/RTP/HQ
# Namespace: Location
#
# Id: c7742869-4269-40f7-9941-5d32ce9fc2e3
# Name: 1st Floor
# Site Name Hierarchy: Global/RTP/HQ/1st Floor
# Namespace: mapsSummary
#
# Id: c7742869-4269-40f7-9941-5d32ce9fc2e3
# Name: 1st Floor
# Site Name Hierarchy: Global/RTP/HQ/1st Floor
# Namespace: Location
#
# Id: c7742869-4269-40f7-9941-5d32ce9fc2e3
# Name: 1st Floor
# Site Name Hierarchy: Global/RTP/HQ/1st Floor
# Namespace: mapGeometry
#
# Id: 72c05ca2-b309-4517-a9ba-27a4f7a59e2c
# Name: 2nd Floor
# Site Name Hierarchy: Global/RTP/HQ/2nd Floor
# Namespace: mapsSummary
#
# Id: 72c05ca2-b309-4517-a9ba-27a4f7a59e2c
# Name: 2nd Floor
# Site Name Hierarchy: Global/RTP/HQ/2nd Floor
# Namespace: mapGeometry
#
# Id: 72c05ca2-b309-4517-a9ba-27a4f7a59e2c
# Name: 2nd Floor
# Site Name Hierarchy: Global/RTP/HQ/2nd Floor
# Namespace: Location
#
# Id: 2c0f2c76-7b97-4d65-b83f-63f56ae91b4e
# Name: RTP
# ...

# %%
site_health = get_site_health (BASE_URL, SITE_HEALTH_URL, headers)
    
print ("\nPretty print response:\n",json.dumps(site_health,indent=4))
# Out:
# <Response [200]>
#
# Pretty print response:
#  [
#     {
#         "siteName": " All Sites",
#         "siteId": "68b27cdf-11b5-4fe0-bd43-97cd2ca22126",
#         "parentSiteId": null,
#         "parentSiteName": null,
#         "siteType": "area",
#         "latitude": null,
#         "longitude": null,
#         "healthyNetworkDevicePercentage": 100,
#         "healthyClientsPercentage": null,
#         "clientHealthWired": null,
#         "clientHealthWireless": null,
#         "numberOfClients": null,
#         "numberOfNetworkDevice": 3,
#         "networkHealthAverage": 100,
#         "networkHealthAccess": 100,
#         "networkHealthCore": null,
#         "networkHealthDistribution": null,
#         "networkHealthRouter": 100,
#         "networkHealthAP": null,
#         "networkHealthWLC": null,
#         "networkHealthSwitch": 100,
#         "networkHealthWireless": null,
#         "networkHealthOthers": null,
#         "numberOfWiredClients": null,
# ...

# %%
json_tree = json.dumps(site_health,indent=4)
data = json.loads(json_tree)

for site in data:
    site_name = site.get("siteName")
    site_id = site.get("siteId")
    healthy_network_device_percentage = site.get("healthyNetworkDevicePercentage")
    healthy_clients_percentage = site.get("healthyClientsPercentage")
    number_of_clients = site.get("numberOfClients")
    number_of_network_device = site.get("numberOfNetworkDevice")

    # Print the extracted information
    print("Site Name:", site_name)
    print("Site ID:", site_id)
    print("Healthy Network Device Percentage:", healthy_network_device_percentage)
    print("Healthy Clients Percentage:", healthy_clients_percentage)
    print("Number of Clients:", number_of_clients)
    print("Number of Network Devices:", number_of_network_device)
    print()
# Out:
# Site Name:  All Sites
# Site ID: 68b27cdf-11b5-4fe0-bd43-97cd2ca22126
# Healthy Network Device Percentage: 100
# Healthy Clients Percentage: None
# Number of Clients: None
# Number of Network Devices: 3
#
# Site Name: RTP
# Site ID: 2c0f2c76-7b97-4d65-b83f-63f56ae91b4e
# Healthy Network Device Percentage: None
# Healthy Clients Percentage: None
# Number of Clients: None
# Number of Network Devices: None
#
# Site Name: Student-1
# Site ID: a1d14ccf-cb03-41ca-aa17-bffcb8997d4c
# Healthy Network Device Percentage: None
# Healthy Clients Percentage: None
# Number of Clients: None
# Number of Network Devices: None

# %%
#SITE_COUNT_URL
site_count = get_api (BASE_URL, SITE_COUNT_URL, headers)
print ("\nPretty print response:\n",json.dumps(site_count,indent=4))
# Out:
# <Response [200]>
#
# Pretty print response:
#  6

# %%
SITE_ID = '2c0f2c76-7b97-4d65-b83f-63f56ae91b4e'
SITE_ID_URL = '/dna/intent/api/v1/site?siteId='+SITE_ID
site = get_api (BASE_URL, SITE_ID_URL, headers)
print ("\nPretty print response:\n",json.dumps(site,indent=4))
# Out:
# <Response [200]>
#
# Pretty print response:
#  {
#     "parentId": "68b27cdf-11b5-4fe0-bd43-97cd2ca22126",
#     "additionalInfo": [
#         {
#             "nameSpace": "Location",
#             "attributes": {
#                 "addressInheritedFrom": "2c0f2c76-7b97-4d65-b83f-63f56ae91b4e",
#                 "type": "area"
#             }
#         }
#     ],
#     "name": "RTP",
#     "instanceTenantId": "662079cb4939f459d3890116",
#     "id": "2c0f2c76-7b97-4d65-b83f-63f56ae91b4e",
#     "siteHierarchy": "68b27cdf-11b5-4fe0-bd43-97cd2ca22126/2c0f2c76-7b97-4d65-b83f-63f56ae91b4e",
#     "siteNameHierarchy": "Global/RTP"
# }

# %%
ISSUES_URL = url = '/dna/intent/api/v1/issues'
issues_list = get_api(BASE_URL, ISSUES_URL, headers)
print ("\nPretty print response:\n",json.dumps(issues_list,indent=4))
# Out:
# <Response [200]>
#
# Pretty print response:
#  [
#     {
#         "issueId": "729ca016-798b-42ef-8a34-a78476cf1d31",
#         "name": "Excessive time lag between Cisco DNA Center and device \"isr4331.dcloud.cisco.com\"",
#         "siteId": "",
#         "deviceId": "28d5bb60-79c5-4dec-b2f6-97404a108cbc",
#         "deviceRole": "",
#         "aiDriven": "No",
#         "clientMac": "",
#         "issue_occurence_count": 1,
#         "status": "active",
#         "priority": "",
#         "category": "",
#         "last_occurence_time": 1738634630000
#     }
# ]

# %%
# Get list of issues
#import requests

# Define variables
#dnac_ip = "dnac-79.infra.ciscomsx.com"
#username = "admin"
#password = "CiscoVMS100%"

#token = get_token(dnac_ip, username, password)

url = 'https://198.18.129.100/dna/intent/api/v1/issues'
#url='https://dnac-79.infra.ciscomsx.com/dna/intent/api/v1/name=<name>&ssiteId=<699dd754-c059-46e0-9968-0684cb6bf647>&type=<type>&offset=<offset>&limit=<limit>'

#site?siteId=<699dd754-c059-46e0-9968-0684cb6bf647>'

headers = {'content-type': 'application/json','x-auth-token': token}

response = requests.get(url, headers=headers, verify=False)

if response.status_code == 200:
    data = response.json()
    print ("\nPretty print response:\n",json.dumps(data,indent=4))
    #do something with the response data
else:
    print('Error: ', response.status_code)
# Out:
# Pretty print response:
#  {
#     "version": "1.0",
#     "totalCount": "1",
#     "response": [
#         {
#             "issueId": "729ca016-798b-42ef-8a34-a78476cf1d31",
#             "name": "Excessive time lag between Cisco DNA Center and device \"isr4331.dcloud.cisco.com\"",
#             "siteId": "",
#             "deviceId": "28d5bb60-79c5-4dec-b2f6-97404a108cbc",
#             "deviceRole": "",
#             "aiDriven": "No",
#             "clientMac": "",
#             "issue_occurence_count": 1,
#             "status": "active",
#             "priority": "",
#             "category": "",
#             "last_occurence_time": 1738634630000
#         }
#     ]
# }

# %%
data
# Out:
# {'version': '1.0',
#  'totalCount': '1',
#  'response': [{'issueId': '729ca016-798b-42ef-8a34-a78476cf1d31',
#    'name': 'Excessive time lag between Cisco DNA Center and device "isr4331.dcloud.cisco.com"',
#    'siteId': '',
#    'deviceId': '28d5bb60-79c5-4dec-b2f6-97404a108cbc',
#    'deviceRole': '',
#    'aiDriven': 'No',
#    'clientMac': '',
#    'issue_occurence_count': 1,
#    'status': 'active',
#    'priority': '',
#    'category': '',
#    'last_occurence_time': 1738634630000}]}

# %%
# Issue name and ID
issues = data['response']
issue_summary = []

for issue in issues:
    issue_name = issue['name']
    issue_id = issue['issueId']
    issue_summary.append((issue_name, issue_id))

# Determine the maximum length of issue names for formatting
max_issue_name_length = max(len(issue[0]) for issue in issue_summary)

# Print the header
header_format = f"{'Issue Name':<{max_issue_name_length + 2}} Issue ID"
print(header_format)
print("-" * len(header_format))

# Print the issue names and issue IDs in columns
for issue_name, issue_id in issue_summary:
    print(f"{issue_name:<{max_issue_name_length + 2}} {issue_id}")
# Out:
# Issue Name                                                                          Issue ID
# --------------------------------------------------------------------------------------------
# Excessive time lag between Cisco DNA Center and device "isr4331.dcloud.cisco.com"   729ca016-798b-42ef-8a34-a78476cf1d31

# %%
# Topology
VLANS_URL = '/dna/intent/api/v1/topology/vlan/vlan-names'
#L3_TOPOLOGY_URL = '/dna/intent/api/v1/topology/l3/ISIS'

token = get_token(dnac_ip, username, password)
headers = {'content-type': 'application/json','x-auth-token': token}

# %%
SITE_TOPOLOGY_URL = '/dna/intent/api/v1/topology/site-topology'
site_topology_list = get_api(BASE_URL, SITE_TOPOLOGY_URL, headers)
print ("\nPretty print response:\n",json.dumps(site_topology_list,indent=4))
# Out:
# <Response [200]>
#
# Pretty print response:
#  {
#     "sites": [
#         {
#             "id": "18d26268-df22-473c-86af-55f9ecdd3dca",
#             "name": "HQ",
#             "parentId": "2c0f2c76-7b97-4d65-b83f-63f56ae91b4e",
#             "latitude": "35.854988",
#             "longitude": "-78.875495",
#             "locationType": "building",
#             "locationAddress": "7025 Kit Creek Road, Morrisville, North Carolina 27560, United States",
#             "locationCountry": "United States",
#             "groupNameHierarchy": "Global/RTP/HQ",
#             "displayName": "1688692"
#         },
#         {
#             "id": "c7742869-4269-40f7-9941-5d32ce9fc2e3",
#             "name": "1st Floor",
#             "parentId": "18d26268-df22-473c-86af-55f9ecdd3dca",
#             "latitude": "",
#             "longitude": "",
#             "locationType": "floor",
#             "locationAddress": "7025 Kit Creek Road, Morrisville, North Carolina 27560, United States",
# ...

# %%
NETWORK_HEALTH_URL = '/dna/intent/api/v1/network-health'
network_health_list = get_api(BASE_URL, NETWORK_HEALTH_URL, headers)
print ("\nPretty print response:\n",json.dumps(network_health_list,indent=4))
# Out:
# <Response [200]>
#
# Pretty print response:
#  [
#     {
#         "time": "2025-02-04T15:25:00.000+0000",
#         "healthScore": 100,
#         "totalCount": 3,
#         "goodCount": 3,
#         "noHealthCount": 0,
#         "fairCount": 0,
#         "badCount": 0,
#         "maintenanceModeCount": 0,
#         "entity": null,
#         "timeinMillis": 1738682700000
#     }
# ]

# %%
PHYSICAL_TOPOLOGY_URL = '/dna/intent/api/v1/topology/physical-topology'
physical_topology_list = get_api(BASE_URL, PHYSICAL_TOPOLOGY_URL, headers)
print ("\nPretty print response:\n",json.dumps(physical_topology_list,indent=4))
# Out:
# <Response [200]>
#
# Pretty print response:
#  {
#     "nodes": [
#         {
#             "deviceType": "Cisco 4331 Integrated Services Router",
#             "deviceSeries": "Cisco 4000 Series Integrated Services Routers",
#             "label": "isr4331.dcloud.cisco.com",
#             "ip": "198.19.2.1",
#             "softwareVersion": "17.9.5a",
#             "nodeType": "device",
#             "family": "Routers",
#             "platformId": "ISR4331/K9",
#             "role": "BORDER ROUTER",
#             "roleSource": "AUTO",
#             "customParam": {
#                 "x": 0,
#                 "y": 0,
#                 "cx": 0,
#                 "cy": 0,
#                 "parentNodeId": null,
#                 "label": null,
#                 "attributeInfo": {},
#                 "id": null
#             },
#             "additionalInfo": {
#                 "macAddress": "68:ca:e4:b0:0f:c0"
#             },
# ...

# %%
# Physical topology with device type, name, IP and Node Type
json_tree = json.dumps(physical_topology_list,indent=4)
data = json.loads(json_tree)

# Display deviceType, label, ip, and nodeType
for node in data['nodes']:
    print("Device Type:", node['deviceType'])
    print("Label:", node['label'])
    print("IP:", node['ip'])
    print("Node Type:", node['nodeType'])
    print()
# Out:
# Device Type: Cisco 4331 Integrated Services Router
# Label: isr4331.dcloud.cisco.com
# IP: 198.19.2.1
# Node Type: device
#
# Device Type: Cisco Catalyst 9300 Switch
# Label: c9300-1.dcloud.cisco.com
# IP: 198.19.1.2
# Node Type: device
#
# Device Type: Cisco Catalyst 9300 Switch
# Label: c9300-2.dcloud.cisco.com
# IP: 198.19.2.2
# Node Type: device
#
# Device Type: cloud node
# Label: cloud node
# IP: UNKNOWN
# Node Type: cloud node

# %%
L3_TOPOLOGY_URL = '/dna/intent/api/v1/topology/l3/OSPF'
l3_topology_list = get_api(BASE_URL, L3_TOPOLOGY_URL, headers)
print ("\nPretty print response:\n",json.dumps(l3_topology_list,indent=4))
# Out:
# <Response [200]>
#
# Pretty print response:
#  {
#     "nodes": [
#         {
#             "deviceType": "Cisco 4331 Integrated Services Router",
#             "deviceSeries": "Cisco 4000 Series Integrated Services Routers",
#             "label": "isr4331.dcloud.cisco.com",
#             "ip": "198.19.2.1",
#             "softwareVersion": "17.9.5a",
#             "nodeType": "device",
#             "family": "Routers",
#             "platformId": "ISR4331/K9",
#             "role": "BORDER ROUTER",
#             "roleSource": "AUTO",
#             "customParam": {
#                 "x": 0,
#                 "y": 0,
#                 "cx": 0,
#                 "cy": 0,
#                 "parentNodeId": null,
#                 "label": null,
#                 "attributeInfo": {},
#                 "id": null
#             },
#             "additionalInfo": {
#                 "macAddress": "68:ca:e4:b0:0f:c0"
#             },
# ...

# %%
# L3 topology 
json_tree = json.dumps(l3_topology_list,indent=4)
data = json.loads(json_tree)

# Display deviceType, label, ip, and nodeType
for node in data['nodes']:
    print("Device Type:", node['deviceType'])
    print("Device Series:", node['deviceSeries'])
    print("Family:", node['family'])
    print("Role:", node['role'])
    print("IP:", node['ip'])
    print("Node Type:", node['nodeType'])
    print()
# Out:
# Device Type: Cisco 4331 Integrated Services Router
# Device Series: Cisco 4000 Series Integrated Services Routers
# Family: Routers
# Role: BORDER ROUTER
# IP: 198.19.2.1
# Node Type: device
#
# Device Type: Cisco Catalyst 9300 Switch
# Device Series: Cisco Catalyst 9300 Series Switches
# Family: Switches and Hubs
# Role: ACCESS
# IP: 198.19.1.2
# Node Type: device
#
# Device Type: Cisco Catalyst 9300 Switch
# Device Series: Cisco Catalyst 9300 Series Switches
# Family: Switches and Hubs
# Role: ACCESS
# IP: 198.19.2.2
# Node Type: device
#
# Device Type: cloud node
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 8
#       6 for node in data['nodes']:
#       7     print("Device Type:", node['deviceType'])
# ----> 8     print("Device Series:", node['deviceSeries'])
#       9     print("Family:", node['family'])
#      10     print("Role:", node['role'])
#
# ...

# %%
#System Health 

# Get System Health
def get_system_health (BASE_URL, URL, headers):
    response = requests.get(BASE_URL + URL,
                            headers=headers, verify=False)
    print(response)
    return response.json()

token = get_token(dnac_ip, username, password)
#headers = {'content-type': 'application/json'}
headers = {'content-type': 'application/json','x-auth-token': token}

SYSTEM_HEALTH_URL = '/dna/intent/api/v1/diagnostics/system/health'

system_health_list = get_system_health (BASE_URL, SYSTEM_HEALTH_URL, headers)
print ("\nPretty print response:\n",json.dumps(system_health_list,indent=4))
# Out:
# <Response [200]>
#
# Pretty print response:
#  {
#     "healthEvents": [
#         {
#             "severity": 1,
#             "hostname": "198.18.129.100",
#             "instance": "198.18.129.100:Managed Services",
#             "subDomain": "Platform Services",
#             "domain": "Cisco DNA Center System",
#             "description": " Managed Service elasticsearch is RUNNING with 24 restarts ",
#             "state": "NOTOK",
#             "timestamp": "1738683727662",
#             "status": "Error"
#         },
#         {
#             "severity": 3,
#             "hostname": "198.18.129.100",
#             "instance": "198.18.129.100:Certificate",
#             "subDomain": "Certificate",
#             "domain": "Cisco DNA Center System",
#             "description": "Built in Certificate with serial number D9D241A8A91F7BE683B03AA2271A5438FF093FE is Ok.",
#             "state": "OK",
#             "timestamp": "1738231200083",
#             "status": "Ok"
# ...

# %%
HEALTH_COUNT_URL = '/dna/intent/api/v1/diagnostics/system/health/count'
health_count_list = get_system_health (BASE_URL, HEALTH_COUNT_URL, headers)
print ("\nPretty print response:\n",json.dumps(health_count_list,indent=4))
# Out:
# <Response [200]>
#
# Pretty print response:
#  {
#     "count": 26
# }

# %%
SYSTEM_PERFORMANCE ='/api/v1/diagnostics/system/performance'
system_performance_list = get_system_health (BASE_URL, SYSTEM_PERFORMANCE, headers)
print ("\nPretty print response:\n",json.dumps(system_performance_list,indent=4))
# Out:
# <Response [200]>
#
# Pretty print response:
#  {
#     "hostName": "198.18.129.100",
#     "version": "1",
#     "kpis": {
#         "cpu": {
#             "utilization": "9.62",
#             "units": "percent"
#         },
#         "memory": {
#             "utilization": "67.41",
#             "units": "percent"
#         },
#         "network tx_rate": {
#             "utilization": "1575.12",
#             "units": "kbps"
#         },
#         "network rx_rate": {
#             "utilization": "1913.68",
#             "units": "kbps"
#         }
#     }
# }

# %%
l3_topology_list
# Out:
# {'nodes': [{'deviceType': 'Cisco 4331 Integrated Services Router',
#    'deviceSeries': 'Cisco 4000 Series Integrated Services Routers',
#    'label': 'isr4331.dcloud.cisco.com',
#    'ip': '198.19.2.1',
#    'softwareVersion': '17.9.5a',
#    'nodeType': 'device',
#    'family': 'Routers',
#    'platformId': 'ISR4331/K9',
#    'role': 'BORDER ROUTER',
#    'roleSource': 'AUTO',
#    'customParam': {'x': 0,
#     'y': 0,
#     'cx': 0,
#     'cy': 0,
#     'parentNodeId': None,
#     'label': None,
#     'attributeInfo': {},
#     'id': None},
#    'additionalInfo': {'macAddress': '68:ca:e4:b0:0f:c0'},
#    'id': '28d5bb60-79c5-4dec-b2f6-97404a108cbc'},
#   {'deviceType': 'Cisco Catalyst 9300 Switch',
#    'deviceSeries': 'Cisco Catalyst 9300 Series Switches',
#    'label': 'c9300-1.dcloud.cisco.com',
#    'ip': '198.19.1.2',
#    'softwareVersion': '17.9.2',
#    'nodeType': 'device',
#    'family': 'Switches and Hubs',
#    'platformId': 'C9300-48U',
#    'role': 'ACCESS',
# ...

# %%
from anytree import Node, RenderTree

# Parse JSON data
parsed_data = physical_topology_list

# Create a dictionary to store nodes by their IDs
nodes_dict = {}

# Create the root node
root = Node("Root")

# Create nodes and store them in the dictionary
for node_data in parsed_data['nodes']:
    node_id = node_data['id']
    label = node_data['label']
    parent_id = node_data['customParam']['parentNodeId']
    
    node = Node(label, parent=nodes_dict.get(parent_id, root))
    nodes_dict[node_id] = node

# Print the tree
for pre, fill, node in RenderTree(root):
    print(f"{pre}{node.name}")
# Out:
# Root
# ├── isr4331.dcloud.cisco.com
# ├── c9300-1.dcloud.cisco.com
# ├── c9300-2.dcloud.cisco.com
# └── cloud node
